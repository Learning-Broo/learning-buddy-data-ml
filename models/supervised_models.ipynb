# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# stud_progress = pd.read_csv('../output/student_progress.csv')
